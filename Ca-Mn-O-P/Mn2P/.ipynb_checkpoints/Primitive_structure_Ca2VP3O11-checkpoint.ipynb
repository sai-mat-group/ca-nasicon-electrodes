# %%
from pymatgen.core import Structure

# %%
import os

# %%
os.chdir('/home/smart/Ankit/VASP/Ca-V-O-P/Ca2VP3O11')

# %%
structure = Structure.from_file("EntryWithCollCode165407.cif")
print(structure)
# Out:
# Full Formula (Ca8 V4 P12 O44)
# Reduced Formula: Ca2VP3O11
# abc   :   6.391000   6.636200  19.071000
# angles:  90.000000  99.260000  90.000000
# Sites (68)
#   #  SP          a        b        c
# ---  ----  -------  -------  -------
#   0  Ca2+  0.67011  0.85476  0.57768
#   1  Ca2+  0.32989  0.35476  0.92232
#   2  Ca2+  0.32989  0.14524  0.42232
#   3  Ca2+  0.67011  0.64524  0.07768
#   4  Ca2+  0.67074  0.5106   0.77244
#   5  Ca2+  0.32926  0.0106   0.72756
#   6  Ca2+  0.32926  0.4894   0.22756
#   7  Ca2+  0.67074  0.9894   0.27244
#   8  V3+   0.94683  0.35573  0.62229
#   9  V3+   0.05317  0.85573  0.87771
#  10  V3+   0.05317  0.64427  0.37771
#  11  V3+   0.94683  0.14427  0.12229
#  12  P5+   0.42809  0.34579  0.58817
#  13  P5+   0.57191  0.84579  0.91183
#  14  P5+   0.57191  0.65421  0.41183
#  15  P5+   0.42809  0.15421  0.08817
#  16  P5+   0.17104  0.70579  0.54854
#  17  P5+   0.82896  0.20579  0.95146
#  18  P5+   0.82896  0.29421  0.45146
# ...

# %%
from pymatgen.core.composition import Composition
from pymatgen.core.lattice import Lattice
from pymatgen.core.operations import SymmOp
from pymatgen.core.periodic_table import Element, Species
from pymatgen.core.structure import (
    IMolecule,
    IStructure,
    Molecule,
    Structure,
    StructureError,
)

s = structure.get_primitive_structure()
print(s)
# Out:
# Full Formula (Ca8 V4 P12 O44)
# Reduced Formula: Ca2VP3O11
# abc   :   6.391000   6.636200  19.071000
# angles:  90.000000  99.260000  90.000000
# Sites (68)
#   #  SP          a        b        c
# ---  ----  -------  -------  -------
#   0  Ca2+  0.67011  0.85476  0.57768
#   1  Ca2+  0.32989  0.35476  0.92232
#   2  Ca2+  0.32989  0.14524  0.42232
#   3  Ca2+  0.67011  0.64524  0.07768
#   4  Ca2+  0.67074  0.5106   0.77244
#   5  Ca2+  0.32926  0.0106   0.72756
#   6  Ca2+  0.32926  0.4894   0.22756
#   7  Ca2+  0.67074  0.9894   0.27244
#   8  V3+   0.94683  0.35573  0.62229
#   9  V3+   0.05317  0.85573  0.87771
#  10  V3+   0.05317  0.64427  0.37771
#  11  V3+   0.94683  0.14427  0.12229
#  12  P5+   0.42809  0.34579  0.58817
#  13  P5+   0.57191  0.84579  0.91183
#  14  P5+   0.57191  0.65421  0.41183
#  15  P5+   0.42809  0.15421  0.08817
#  16  P5+   0.17104  0.70579  0.54854
#  17  P5+   0.82896  0.20579  0.95146
#  18  P5+   0.82896  0.29421  0.45146
# ...

# %%
from pymatgen.core.structure import Element
from pymatgen.io.vasp.sets import MPRelaxSet
from pymatgen.io.vasp.inputs import Potcar
#import os
#os.chdir('/home/smart/Ankit/VASP/Ca-Ti-Si-O/Ternary/Ca Si O3 -P1')

from pymatgen.io.vasp.sets import MPRelaxSet
from pymatgen.io.vasp.inputs import Kpoints
kpoints = Kpoints.automatic(32)
relaxset = MPRelaxSet(s,user_kpoints_settings=kpoints)
relaxset.write_input('Ca2VP3O11')
